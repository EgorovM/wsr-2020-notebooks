# %%
# data
# prediction

# %%
import pandas as pd

# %%
df_train = pd.read_csv('train.csv')

# %%
df_train.head()
# Out:
#    feature1   feature2   feature3   feature4   feature5  feature6  feature7  \
# 0         4  95.950150  87.221940  89.534122  81.423258  1.317590  1.301059
# 1         5  83.244760  59.224400  59.506081  36.126175  1.311510  1.372050
# 2         2  23.035850  26.647510  21.192566  25.010514  0.614232  0.435817
# 3         4  81.756699  79.833804  76.282833  75.275775  1.312596  1.149324
# 4         2  67.485250  69.699016  57.442709  59.574464  0.548263  0.521345
#
#    feature8   feature9  feature10  ...  feature73  feature74  feature75  \
# 0   96.1190  20.285800  36.105357  ...       4.10   4.053600   3.944244
# 1  192.9810  25.192187  67.233835  ...       2.40   2.402249   2.259897
# 2   18.0583  18.243490   9.029150  ...       5.10   4.242641   4.873514
# 3   81.4820  28.789976  32.890369  ...       3.62   3.309751   3.413039
# 4   70.8405  39.638078  35.420250  ...       6.00   6.000000   6.000000
#
#    feature76  feature77  feature78  feature79  feature80  feature81  \
# ...

# %%
target = df_train['critical_temperature']
train_data = df_train.drop('critical_temperature', axis=1)

# %%
train_data.head()
# Out:
#    feature1   feature2   feature3   feature4   feature5  feature6  feature7  \
# 0         4  95.950150  87.221940  89.534122  81.423258  1.317590  1.301059
# 1         5  83.244760  59.224400  59.506081  36.126175  1.311510  1.372050
# 2         2  23.035850  26.647510  21.192566  25.010514  0.614232  0.435817
# 3         4  81.756699  79.833804  76.282833  75.275775  1.312596  1.149324
# 4         2  67.485250  69.699016  57.442709  59.574464  0.548263  0.521345
#
#    feature8   feature9  feature10  ...  feature72  feature73  feature74  \
# 0   96.1190  20.285800  36.105357  ...       4.25       4.10   4.053600
# 1  192.9810  25.192187  67.233835  ...       2.60       2.40   2.402249
# 2   18.0583  18.243490   9.029150  ...       4.50       5.10   4.242641
# 3   81.4820  28.789976  32.890369  ...       3.50       3.62   3.309751
# 4   70.8405  39.638078  35.420250  ...       6.00       6.00   6.000000
#
# ...

# %%
target.head()
# Out:
# 0    21.50
# 1    62.00
# 2     0.29
# 3    19.50
# 4     5.36
# Name: critical_temperature, dtype: float64

# %%
import sklearn

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
model.fit(train_data, target)
# Out:
# LinearRegression()

# %%
df_test = pd.read_csv('test.csv')

# %%
model.predict(df_test)
# Out:
# array([ 69.38523776,  21.59580162,  21.04717688, ...,  24.01820592,
#         13.83126116, -17.52712392])

# %%
from pprint import pprint as pp

# %%
pp(model.predict(df_test)[:5])
# Out:
# array([69.38523776, 21.59580162, 21.04717688, 67.31234028, 33.94042546])

# %%
df_test.head()
# Out:
#    feature1    feature2   feature3    feature4   feature5  feature6  feature7  \
# 0         5   82.324574  88.533544   64.110667  72.640059  1.418486  1.179961
# 1         4  115.438500  90.562624  107.211420  88.713057  1.308571  1.157701
# 2         4   92.290900  83.842290   87.295606  79.318618  1.331889  1.300022
# 3         5   72.324650  51.227894   58.637102  34.924853  1.444612  1.306314
# 4         4   90.142263  58.462879   66.935044  36.272055  1.178649  1.019134
#
#     feature8   feature9  feature10  ...  feature72  feature73  feature74  \
# 0  122.90607  38.757614  48.331141  ...        2.4   2.151429   2.352158
# 1  122.45400  37.743936  47.516249  ...        4.0   3.632000   3.722419
# 2   81.48200  20.872340  30.558629  ...        4.0   3.870000   3.662842
# 3  121.32760  20.998358  40.053512  ...        2.4   2.079231   2.352158
# 4  124.90825  34.237393  53.101375  ...        3.0   2.571429   2.828427
#
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(train_data, target, test_size=0.3)

# %%
X_train.head()
# Out:
#        feature1   feature2   feature3   feature4   feature5  feature6  \
# 3768          2  51.858690  34.266823  31.692442  19.988230  0.334290
# 1137          4  93.530600  56.599724  68.451761  36.573884  1.168103
# 15309         4  89.641717  57.920761  66.695994  36.131766  1.179959
# 10554         3  87.468333  84.426500  82.555758  78.550862  1.041270
# 6742          2  71.176500  72.339300  71.161657  72.333927  0.692939
#
#        feature7   feature8   feature9  feature10  ...  feature72  feature73  \
# 3768   0.533600   82.09538  18.822537  41.047690  ...       4.00   3.571429
# 1137   1.334286  141.25060  12.580321  56.763654  ...       2.25   2.077107
# 15309  0.951068  124.11660  36.697761  52.627816  ...       2.75   2.296429
# 10554  0.978327   71.75500  32.816000  29.905282  ...       5.00   4.500000
# 6742   0.317063    2.90700  58.394700   1.453500  ...       3.50   3.900000
#
#        feature74  feature75  feature76  feature77  feature78  feature79  \
# ...

# %%
X_test.head()
# Out:
#        feature1    feature2    feature3    feature4    feature5  feature6  \
# 15866         5  102.654174   57.601702   76.169456   35.597480  1.388429
# 3729          2  202.973485  200.971179  202.884579  200.892411  0.692709
# 16611         6   75.283478   47.468925   59.282465   32.808988  1.592211
# 12580         2   96.426091   16.613391   40.703803   10.274709  0.188775
# 3838          4   76.444563   51.272799   59.356672   34.956275  1.199541
#
#        feature7    feature8   feature9  feature10  ...  feature72  feature73  \
# 15866  1.559000  191.200600  10.408466  65.587364  ...   2.600000   2.258621
# 3729   0.645328   12.013831  61.650913   6.006916  ...   5.000000   5.000000
# 16611  1.598088  122.906070  12.460320  46.845147  ...   2.333333   2.095385
# 12580  0.692434  174.827818   0.627305  87.413909  ...   4.000000   2.173913
# 3838   1.291770  121.327600  14.299319  43.823354  ...   2.250000   2.076982
#
# ...

# %%
y_train.head()
# Out:
# 3768      4.55
# 1137     91.00
# 15309     3.92
# 10554    14.80
# 6742      5.30
# Name: critical_temperature, dtype: float64

# %%
y_test.head()
# Out:
# 15866    28.10
# 3729      1.84
# 16611    22.00
# 12580     4.12
# 3838     92.30
# Name: critical_temperature, dtype: float64

# %%
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_predicts = model.predict(X_test)

# %%
y_test
# Out:
# 15866    28.10
# 3729      1.84
# 16611    22.00
# 12580     4.12
# 3838     92.30
#          ...
# 10768     1.80
# 1275      6.35
# 12891     9.60
# 1348     18.10
# 3058     48.00
# Name: critical_temperature, Length: 5100, dtype: float64

# %%
from sklearn.metrics import mean_squared_error

# %%
mean_squared_error(y_predicts, y_test)
# Out:
# 310.01279751754953

# %%
from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier

# %%
model = RandomForestRegressor()
model.fit(X_train, y_train)
# Out:
# RandomForestRegressor()

# %%
# Regressor, Regression
# Classificator, Classification

# Типы данных
# Вещественные
# Категориальные
# Порядковые
# Бинарные

# Предсказываем
# критическая температура - вещественные (регрессии)

# тип материала (эбонит, серебро...) - категориальный (классификация)
# это эбонит? (да, нет) - бинарный (классификация)

# %%
y_predicts = model.predict(X_test)

# %%
y_test
# Out:
# 15866    28.10
# 3729      1.84
# 16611    22.00
# 12580     4.12
# 3838     92.30
#          ...
# 10768     1.80
# 1275      6.35
# 12891     9.60
# 1348     18.10
# 3058     48.00
# Name: critical_temperature, Length: 5100, dtype: float64

# %%
mean_squared_error(y_predicts, y_test)
# Out:
# 93.86436608564017

# %%
y_predicts = model.predict(df_test)

# %%
pd.DataFrame(y_predicts).to_csv('answer.csv', index=False)

# %%
"""
1. Загрузить данные // pd.read_csv('train.csv')
2. Обработать их // target, data_train
3. Разбить train на тестовую и тренировочную train_test_split
4. Обучить модель, проверить на mean_squared_error, accuracity
5. Если результат плачевный, то обучить другую модель, шаг 4
6. Если все ок, то предсказать для test данных
7. Сохранить данные // to_csv
8. Отправить(Опционально)
"""
